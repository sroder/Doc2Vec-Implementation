# %%
# Read the data
# Read Excel with Pandas
import pandas as pd
from pandas import ExcelFile
df = pd.read_excel('laufzeit_vertarg.xlsx',sheet_name = 'Sheet3')
df.head()
# Out:
#                                         Beschreibung          Skript
# 0  Das Feld End Date of Policy muss mit dem Wert ...  CheckValue_SAP
# 1  Das Feld End Date of Policy wird mit dem Wert ...  CheckValue_SAP
# 2  Das Feld Day Rule enthält den Wert 360 Days Pe...  CheckValue_SAP
# 3             Tabelle hat immer noch einen Eintrag\n  CheckValue_SAP
# 4  Tabelle im UIBB "Policy Sections" enthält eine...  CheckValue_SAP

# %%
# # check the description of Dataframe, which we read in previous step from the excel sheet
df.describe()
# Out:
#                                    Beschreibung                       Skript
# count                                       998                          998
# unique                                      696                           18
# top     Erfolgsmeldung: Data has been savedzwei  SAPEdit("Field Name").Set X
# freq                                         15                          276

# %%
# reading the scripts as sentences from the file
sentences_x = []
max_rows = 998
for i in df['Beschreibung']:
    sentences_x.append(i)
sentences_x
# Out:
# ['Das Feld End Date of Policy muss mit dem Wert 01.01.2016 vorbelegt werden. ',
#  'Das Feld End Date of Policy wird mit dem Wert 30.12.9999 vorbelegt. ',
#  'Das Feld Day Rule enthält den Wert 360 Days Per Year Rule. ',
#  'Tabelle hat immer noch einen Eintrag\n',
#  'Tabelle im UIBB "Policy Sections" enthält einen Eintrag.',
#  'Es bleibt bei einem Eintrag.',
#  'Tabelle hat nur noch einen Eintrag.\n',
#  'Es existieren wieder 2 Einträge.',
#  'Der Eintrag verschwindet',
#  'Die Klausel kann gespeichert werden.\n',
#  "Name of Clause/Term & Condition' wird mit 'Both to Blame Collision Clause' befüllt.\n",
#  'Der Detailbereich wird eingabebereit angezeigt.\n',
#  "Name of Country' wird mit 'Germany' befüllt.",
#  "Name of Region' wird mit 'Bavaria' befüllt.",
#  "Das Feld 'Country' wird zum Pflichtfeld.",
#  "Das Feld 'Name of Policyholder Type' wird mit 'Secondary Policyholder' belegt.",
#  'Daten können gespeichert werden',
#  'Eingaben können gespeichert werden.',
# ...

# %%
# assigning a list of labels for each skript, the labels are mimics of actual sentences
# need to test here if Test sentences can be put as labels
LabelList = []
for i in range(max_rows):
    LabelList.append(df['Skript'][i])

# %%
len(LabelList)
# Out:
# 998

# %%
# we instantiate the Sklearn TF-IDF Vectorizer and transform our documents into the TF-IDF matrix
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(sentences_x)
print (tfidf_matrix.shape)
# Out:
# (998, 503)

# %%
rows, cols = tfidf_matrix.nonzero()
rows_label, cols_label = tfidf_matrix_Label.nonzero()

# %%
len(cols_label)
# Out:
# 1904

# %%
# get the TF-IDF matrix for  label list
tfidf_matrix_Label = tfidf_vectorizer.fit_transform(LabelList)
print (tfidf_matrix_Label.shape)
# Out:
# (998, 24)

# %%
# cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(tfidf_matrix, tfidf_matrix_Label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3521ce17b2e0> in <module>()
#       1 # cosine similarity
#       2 from sklearn.metrics.pairwise import cosine_similarity
# ----> 3 cosine_similarity(tfidf_matrix, tfidf_matrix_Label)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#     915     # to avoid recursive import
#     916
# --> 917     X, Y = check_pairwise_arrays(X, Y)
#     918
#     919     X_normalized = normalize(X, copy=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype)
#     121         raise ValueError("Incompatible dimension for X and Y matrices: "
#     122                          "X.shape[1] == %d while Y.shape[1] == %d" % (
# --> 123                              X.shape[1], Y.shape[1]))
# ...
